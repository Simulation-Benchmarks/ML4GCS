# %%
import matplotlib.pyplot as plt
import seaborn
from evaluation.groups_and_colors import mass_cmap
from process_map_files import get_maps_and_distance, get_result_name_and_year

idx1 = 350
idx2 = 356

name1, year1 = get_result_name_and_year(idx1, '/home/jovyan/shared_folder/data/spe11b/spe11b_metadata_dt50y.json')
print(name1, year1)

name2, year2 = get_result_name_and_year(idx2, '/home/jovyan/shared_folder/data/spe11b/spe11b_metadata_dt50y.json')
print(name2, year2)

# %%
image1, image2, distance = get_maps_and_distance(idx1, idx2, '/home/jovyan/shared_folder/data/spe11b/spe11b_tmco2_dt50y.npz', '/home/jovyan/shared_folder/data/spe11b/spe11b_metadata_dt50y.json')

plt.subplot(211)
plt.imshow(image1, interpolation='none', origin='lower', aspect='auto', cmap=mass_cmap)
plt.xticks([])
plt.yticks([])

plt.subplot(212)
plt.imshow(image2, interpolation='none', origin='lower', aspect='auto', cmap=mass_cmap)
plt.xticks([])
plt.yticks([])

plt.title(f'distance({name1}, {name2}) = {distance:.2e} kg.m')
plt.show()
