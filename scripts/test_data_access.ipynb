# %%
from process_map_files import get_maps_and_distance, get_result_name_and_year

name, year = get_result_name_and_year(35)
print(year)
image1, image2, distance = get_maps_and_distance(35, 37, '/home/jovyan/shared_folder/data/spe11b/spe11b_tmco2_dt50y.npz')

# %%
print(image1)

# %%
distance
