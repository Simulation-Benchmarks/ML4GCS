# %% [markdown]
# # ML4GCS
#
# If you opened this notebook on the NFDI JupyterHub, you should have access to the data via `/home/jovyan/shared_folder`.
#
# Here's a simple example for plotting a time series result from the SPE11A dataset:

# %%
import numpy as np
import matplotlib.pyplot as plt

filename = '/home/jovyan/shared_folder/data/ifpen/spe11a/spe11a_time_series.csv'
data = np.genfromtxt(filename, delimiter=',', skip_header=1)

plt.plot(data[:, 0]/60/60, data[:, 3]*1e3)
plt.xlabel('time [h]')
plt.ylabel('mass of gaseous CO2 in Box A [g]')
plt.show()

# %% [markdown]
# See the notebooks and scripts of this [repo](https://github.com/Simulation-Benchmarks/11thSPE-CSP/) for further examples.
