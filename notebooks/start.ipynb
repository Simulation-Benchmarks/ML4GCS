# %% [markdown]
# # ML4GCS
#
# If you opened this notebook on the NFDI JupyterHub, you should have access to the data via `/home/jovyan/shared_folder`. If you are working locally, the required data will be downloaded on demand.
#
# You can choose from the following benchmark scenarios:
#
# * History matching SPE11B data: [description](../doc/spe11.md), [notebook](spe11b_task_1.ipynb)
# * Transfer learning between FluidFlower rigs: [description](../doc/fluidflower.md)
