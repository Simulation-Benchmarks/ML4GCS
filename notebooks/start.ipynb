# %% [markdown]
# # ML4GCS
#
# If you opened this notebook on the NFDI JupyterHub, you should have access to the data via `~/shared_folder`.
#
# Here's a simple example for plotting a time series result from the SPE11A dataset:

# %% [markdown]
# a = 5
